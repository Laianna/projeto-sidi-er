# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# # Lendo Arquivos

# %%
df_bert = pd.read_csv(f"Dados/Resultados/BERT/bert_resultado.csv")

# %% [markdown]
# # Analisando Experimentos

# %% [markdown]
# ## BERT

# %%
df_bert
# Out:
#             info  precision    recall  f1-score      support            modelo
# 0              0   0.963409  0.990476  0.976755  2100.000000     hn_balanceado
# 1              1   0.944598  0.811905  0.873239   420.000000     hn_balanceado
# 2       accuracy   0.960714  0.960714  0.960714     0.960714     hn_balanceado
# 3      macro avg   0.954004  0.901190  0.924997  2520.000000     hn_balanceado
# 4   weighted avg   0.960274  0.960714  0.959502  2520.000000     hn_balanceado
# 5              0   0.996293  0.970509  0.983232  3323.000000  hn_desbalanceado
# 6              1   0.869333  0.981928  0.922207   664.000000  hn_desbalanceado
# 7       accuracy   0.972410  0.972410  0.972410     0.972410  hn_desbalanceado
# 8      macro avg   0.932813  0.976218  0.952719  3987.000000  hn_desbalanceado
# 9   weighted avg   0.975149  0.972410  0.973068  3987.000000  hn_desbalanceado
# 10             0   0.988647  0.995238  0.991932  2100.000000     sn_balanceado
# ...

# %% [markdown]
# ## Método 2
